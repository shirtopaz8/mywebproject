# %% [markdown]
# <a href="https://colab.research.google.com/github/shirtopaz8/mywebproject/blob/main/%D7%A9%D7%99%D7%A8_%D7%98%D7%95%D7%A4%D7%96_%D7%94%D7%92%D7%A9%D7%AA_%D7%A4%D7%A8%D7%95%D7%99%D7%A7%D7%98_1_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
FEATURE_COLUMN = "Bravery"                       # שם עמודת המאפיין (X) - מה שממנו נחזה
TARGET_COLUMN = "Quidditch Skills"

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("sahityapalacharla/harry-potter-sorting-dataset")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'harry-potter-sorting-dataset' dataset.
# Path to dataset files: /kaggle/input/harry-potter-sorting-dataset

# %%
import pandas as pd
import os

csv_path = os.path.join(path, "harry_potter_1000_students.csv")
data = pd.read_csv(csv_path)

data.head()
# Out:
#   Blood Status  Bravery  Intelligence  Loyalty  Ambition  Dark Arts Knowledge  \
# 0   Half-blood        9             4        7         5                    0
# 1  Muggle-born        6             8        5         7                    5
# 2   Pure-blood        1             4        7         7                    1
# 3   Pure-blood        9             1        3         4                    1
# 4  Muggle-born        5             9        7         3                    3
#
#    Quidditch Skills  Dueling Skills  Creativity       House
# 0                 8               8           7  Gryffindor
# 1                 6               4           9   Ravenclaw
# 2                 4               4           6  Hufflepuff
# 3                 9              10           1  Gryffindor
# 4                 6               7           9   Ravenclaw

# %%
print(data[[FEATURE_COLUMN, TARGET_COLUMN]].isnull().sum())
# Out:
# Bravery             0
# Quidditch Skills    0
# dtype: int64

# %%
import numpy as np

X = data[FEATURE_COLUMN].to_numpy()
y = data[TARGET_COLUMN].to_numpy()

print("X shape:", X.shape)
print("y shape:", y.shape)
print("X sample:", X[:5])
print("y sample:", y[:5])
# Out:
# X shape: (1000,)
# y shape: (1000,)
# X sample: [9 6 1 9 5]
# y sample: [8 6 4 9 6]

# %%
baseline_prediction = np.mean(y)
print("baseline prediction (always the same value):", baseline_prediction)

baseline_loss = np.mean(np.abs(y - baseline_prediction))
print("baseline loss:", baseline_loss)
# Out:
# baseline prediction (always the same value): 5.46
# baseline loss: 2.2362399999999996

# %%
from sklearn.linear_model import LinearRegression

X_reshaped = X.reshape(-1, 1)
print("X shape before reshape:", X.shape)
print("X shape after reshape:", X_reshaped.shape)

model = LinearRegression()
model.fit(X_reshaped, y)

print("training done")
# Out:
# X shape before reshape: (1000,)
# X shape after reshape: (1000, 1)
# training done

# %%
w = model.coef_[0]
b = model.intercept_

print("w:", w)
print("b:", b)
# Out:
# w: 0.2644254174662321
# b: 4.130997851814717

# %%
sample_x = X[0]
print("sample_x:", sample_x)

manual_prediction = w * sample_x + b
print("manual calculation (w * x + b):", manual_prediction)

sklearn_prediction = model.predict(np.array([[sample_x]]))
print("sklearn predict:", sklearn_prediction[0])
# Out:
# sample_x: 9
# manual calculation (w * x + b): 6.510826609010806
# sklearn predict: 6.510826609010806

# %%
y_hat = model.predict(X_reshaped)

model_loss = np.mean(np.abs(y - y_hat))

print("baseline loss:", baseline_loss)
print("model loss:", model_loss)
# Out:
# baseline loss: 2.2362399999999996
# model loss: 2.152228291283019

# %%
user_input = input("what is your bravery level? (sqft): ")
user_sqft = float(user_input)

predicted_price = model.predict(np.array([[user_sqft]]))[0]

print(" quiditch skills prediction:", predicted_price)
# Out:
# what is your bravery level? (sqft): 7
#  quiditch skills prediction: 5.981975774078342
